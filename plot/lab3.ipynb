# %%
import numpy as np 
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# %% [markdown]
# # Task 1

# %%
data=np.loadtxt('../output/lab_3/task1.txt')

size = data.shape

y_dim = size[1]
x_dim = size[0]

u1_values = data[0:].reshape(x_dim, y_dim)
x = np.linspace(0, 1, x_dim)
y = np.linspace(0, 1, y_dim)
X, Y = np.meshgrid(x, y)

fig = plt.figure(figsize = (14,9))
ax = plt.axes(projection = '3d')
ax.plot_wireframe(X,Y,u1_values, cmap = 'viridis')

# %% [markdown]
# # Task 2

# %%
data=np.loadtxt('../output/lab_3/task2.txt')

size = data.shape

y_dim = size[1]
x_dim = size[0]

u1_values = data[0:].reshape(x_dim, y_dim)
x = np.linspace(0, 1, x_dim)
y = np.linspace(0, 1, y_dim)
X, Y = np.meshgrid(x, y)

fig = plt.figure(figsize = (14,9))
ax = plt.axes(projection = '3d')
ax.plot_wireframe(X,Y,u1_values, cmap = 'viridis')
# Out:
# Bad pipe message: %s [b'0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7\r\nHost: localhost:36581\r\nUs', b'-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.']
# Bad pipe message: %s [b'0.0 Safari/537.36\r\nAccept-Encoding: gzip, defla']
# Bad pipe message: %s [b', br\r\nAccept-Language: ru-RU,ru;q=0.9\r\nCache-Control: max-age=0\r\nReferer: https://miniature-space-garbanzo-w6r5x9rj', b'rcv6r5.github.dev/\r\nX-Request-ID: 33ad7e0984280f1e11dc2ba861c6d135\r\nX-Real-IP: 10.240.2.100\r\nX-Forwarded-Port: 4', b'\r\nX-Forwarded-Scheme: https\r\nX-Original-URI: /\r\nX-S', b'eme: https\r\nsec-fetch-site: same-site\r\nsec-fetch-mode: navigate\r\nsec-fetch-dest: document\r\nsec-ch-']
# ...

# %% [markdown]
# # Task 3

# %%
data=np.loadtxt('../output/lab_3/task1.txt')

size = data.shape

y_dim = size[1]
x_dim = size[0]

u1_values = data[0:].reshape(x_dim, y_dim)
x = np.linspace(0, 1, x_dim)
y = np.linspace(0, 1, y_dim)
X, Y = np.meshgrid(x, y)

fig = plt.figure(figsize = (14,9))
ax = plt.axes(projection = '3d')
ax.plot_wireframe(X,Y,u1_values, cmap = 'viridis')
