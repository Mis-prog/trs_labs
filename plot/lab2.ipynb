# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# # Задание 1

# %% [markdown]
# ## Явная схема

# %%
def exact_solution(x,t):
    return np.exp(t)*np.sinh(x)

# %%
x_values = np.linspace(0, 1, 1000)
t_values = np.linspace(0, 0.5, 1000)

X, T = np.meshgrid(x_values, t_values)

exact_values = exact_solution(X, T)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

surf = ax.plot_surface(X, T, exact_values, cmap='viridis')

ax.set_xlabel('x')
ax.set_ylabel('t')
ax.set_zlabel('Exact Solution')

plt.title('Exact Solution')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig, axs = plt.subplots(3,2, figsize=(15, 15))

N = [1, 2, 3]


for index in N:
    data = np.genfromtxt("../output/lab_2/z1_" + str(index) + ".txt")

    t_values = np.linspace(0, 1, data.shape[1])
    x_values = np.linspace(0, 1, data.shape[0])

    T, X = np.meshgrid(t_values, x_values)
    ax = fig.add_subplot(3, 2, index*2-1 , projection='3d')
    ax.plot_surface(T, X, data, cmap='viridis')


for index in N:
    data = np.genfromtxt("../output/lab_2/z1_error" + str(index) + ".txt")

    t_values = np.linspace(0, 1, data.shape[1])
    x_values = np.linspace(0, 1, data.shape[0])

    T, X = np.meshgrid(t_values, x_values)
    ax = fig.add_subplot(3, 2, index * 2, projection='3d')
    ax.plot_surface(T, X, data, cmap='viridis')

plt.show()

# %% [markdown]
# # Задание 2

# %% [markdown]
# ## Неявная схема

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig, axs = plt.subplots(3,2, figsize=(15, 15))

N = [1, 2, 3]


for index in N:
    data = np.genfromtxt("../output/lab_2/z2_p1" + str(index) + ".txt")

    t_values = np.linspace(0, 1, data.shape[1])
    x_values = np.linspace(0, 1, data.shape[0])

    T, X = np.meshgrid(t_values, x_values)
    ax = fig.add_subplot(3, 2, index*2-1 , projection='3d')
    ax.plot_surface(T, X, data, cmap='viridis')


for index in N:
    data = np.genfromtxt("../output/lab_2/z2_p1_error" + str(index) + ".txt")

    t_values = np.linspace(0, 1, data.shape[1])
    x_values = np.linspace(0, 1, data.shape[0])

    T, X = np.meshgrid(t_values, x_values)
    ax = fig.add_subplot(3, 2, index * 2, projection='3d')
    ax.plot_surface(T, X, data, cmap='viridis')

plt.show()

# %% [markdown]
# ## Схема Кранка Николсона

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig, axs = plt.subplots(3,2, figsize=(15, 15))

N = [1, 2, 3]


for index in N:
    data = np.genfromtxt("../output/lab_2/z2_p2" + str(index) + ".txt")

    t_values = np.linspace(0, 1, data.shape[1])
    x_values = np.linspace(0, 1, data.shape[0])

    T, X = np.meshgrid(t_values, x_values)
    ax = fig.add_subplot(3, 2, index*2-1 , projection='3d')
    ax.plot_surface(T, X, data, cmap='viridis')


for index in N:
    data = np.genfromtxt("../output/lab_2/z2_p2_error" + str(index) + ".txt")

    t_values = np.linspace(0, 1, data.shape[1])
    x_values = np.linspace(0, 1, data.shape[0])

    T, X = np.meshgrid(t_values, x_values)
    ax = fig.add_subplot(3, 2, index * 2, projection='3d')
    ax.plot_surface(T, X, data, cmap='viridis')

plt.show()

# %% [markdown]
# # Задание 3

# %% [markdown]
# ## Консервативная схема

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(15, 15))

N = [0, 1]

for index in N:
    data = np.genfromtxt("../output/lab_2/z3_u" + str(index) + ".txt")

    t_values = np.linspace(0, 1, data.shape[1])
    x_values = np.linspace(0, 1, data.shape[0])

    T, X = np.meshgrid(t_values, x_values)
    ax = fig.add_subplot(2, 2, index + 1, projection='3d')
    ax.plot_surface(T, X, data, cmap='viridis')

for index in N:
    data = np.genfromtxt("../output/lab_2/z3_u_error" + str(index) + ".txt")

    t_values = np.linspace(0, 1, data.shape[1])
    x_values = np.linspace(0, 1, data.shape[0])

    T, X = np.meshgrid(t_values, x_values)
    ax = fig.add_subplot(2, 2, (index + 1) + 2, projection='3d')
    ax.plot_surface(T, X, data, cmap='viridis')

plt.show()
