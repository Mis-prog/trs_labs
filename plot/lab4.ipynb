# %%
import numpy as np
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# %%
path = "../output/lab_4/"

# %%
def u(x, t):
    return np.sin(t + 5 * x) / 6 + np.sin(x - t)

# %%
x_values = np.linspace(0, 2, 1000)
t_values = np.linspace(0, 10, 1000)

X, T = np.meshgrid(x_values, t_values)

exact_values = u(X, T)

fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")

surf = ax.plot_surface(X, T, exact_values, cmap="viridis")

ax.set_xlabel("x")
ax.set_ylabel("t")
ax.set_zlabel("Exact Solution")

plt.title("Exact Solution")
plt.show()

# %% [markdown]
# # Задание 1

# %%
fig, axs = plt.subplots(3,2, figsize=(17, 27))



for i in range(1,3):
    index=i-1
    data = np.genfromtxt(path+"z1_" + str(index) + ".txt")

    t_values = np.linspace(0, 10, data.shape[1])
    x_values = np.linspace(0, 2, data.shape[0])


    T, X = np.meshgrid(t_values, x_values)
    ax = fig.add_subplot(3, 2, i*2-1, projection='3d') 
    ax.plot_surface(T, X, data, cmap='viridis')


for i in range(1,3):
    index=i-1
    data = np.genfromtxt(path+"z1_error_" + str(index) + ".txt")

    t_values = np.linspace(0, 10, data.shape[1])
    x_values = np.linspace(0, 2, data.shape[0])

    T, X = np.meshgrid(t_values, x_values)
    ax = fig.add_subplot(3, 2, i*2 , projection='3d')
    ax.set_title(f'Error = {np.max(data)}')
    ax.plot_surface(T, X, data, cmap='viridis')
    

plt.show()
